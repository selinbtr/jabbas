# %%
import sqlite3
import pandas as pd

# %%
zipcode = pd.read_csv('zip_code_database.csv')

# %%
zipcode.head()
# Out:
#    zip      type  decommissioned primary_city acceptable_cities  \
# 0  501    UNIQUE               0   Holtsville               NaN
# 1  544    UNIQUE               0   Holtsville               NaN
# 2  601  STANDARD               0     Adjuntas               NaN
# 3  602  STANDARD               0       Aguada               NaN
# 4  603  STANDARD               0    Aguadilla             Ramey
#
#                                  unacceptable_cities state  \
# 0                               I R S Service Center    NY
# 1                                 Irs Service Center    NY
# 2  Colinas Del Gigante, Jard De Adjuntas, Urb San...    PR
# 3  Alts De Aguada, Bo Guaniquilla, Comunidad Las ...    PR
# 4  Bda Caban, Bda Esteves, Bo Borinquen, Bo Ceiba...    PR
#
#                 county             timezone area_codes world_region country  \
# 0       Suffolk County     America/New_York        631          NaN      US
# ...

# %%
new_zipcode = zipcode[["zip", "latitude", "longitude"]]

# %%
new_zipcode
# Out:
#          zip  latitude  longitude
# 0        501     40.81     -73.04
# 1        544     40.81     -73.04
# 2        601     18.16     -66.72
# 3        602     18.38     -67.18
# 4        603     18.43     -67.15
# ...      ...       ...        ...
# 42627  99926     55.14    -131.49
# 42628  99927     56.30    -133.57
# 42629  99928     55.45    -131.79
# 42630  99929     56.41    -131.61
# 42631  99950     55.34    -131.64
#
# [42632 rows x 3 columns]

# %%
new_zipcode.to_csv("zipcode.csv", index = False, header = True)

# %%
read_zipcode = pd.read_csv('zipcode.csv')

# %%
read_zipcode.head()
# Out:
#    zip  latitude  longitude
# 0  501     40.81     -73.04
# 1  544     40.81     -73.04
# 2  601     18.16     -66.72
# 3  602     18.38     -67.18
# 4  603     18.43     -67.15

# %%
#create sqlite
cnx = sqlite3.connect('zipcode_db.sqlite')
read_zipcode.to_sql('zipcode', cnx)
